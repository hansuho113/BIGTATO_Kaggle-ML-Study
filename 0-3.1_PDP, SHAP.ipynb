# %% [markdown]
# # PDP (Partial Dependence Plot)
# - 하나의 변수의 변화가 Model에서 어떠한 영향을 미치는지, 또는 두 변수의 상호작용이 어떠한 지점에서 Model에게 영향을 미치는지 확인할 수 있는 Plot
# - y축은 Baseline 대비 Prediction의 변동폭이고 음영은 신뢰구간이라고 생각하면 됨.

# %% [markdown]
# # SHAP (SHapley Additive exPlanations)
# 1. 모델의 예측력과 해석력(트레이드오프)
# 2. 흔히 예측력이 높으나 해석이 힘들 모델을 black box라고 부름
#     - 반면, 선형회귀 같이 전통적인 모델들은 예측성능은 비교적 떨어지지만, ‘변수 X1이 1 증가할때 결과값 y가 몇 증가한다’ 등 직관적인 해석이 가능하는 강점

# %% [markdown]
# - Red arrows는 예측값을 더 높게 하는 변수들의 영향도를 설명한다(SHAP values)
# - Blue arrows는 반대로 지금 예측값을 더 낮게 하는 변수들의 영향도를 나타낸다.
#     - 각각의 arrows의 크기는 변수의 영향도에 대한 양을 나타낸다.
#
#
# > 여기서 base value(왼쪽 상단) 은 train set에서의 모델 평균 예측을 마킹한 것
#
# > output value는 모델의 예측임  가장 큰 영향을 준 변수의 값은 아래에 표시됨

# %%
import PIL.Image as pilimg
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
image = pilimg.open('C:\\Users\\HANSUHO\\Desktop\\SHAP.png')
image.show()
pix = np.array(image)
plt.subplots(figsize=(30,30))
plt.imshow(pix)

# %% [markdown]
# Reference
#
# https://datanetworkanalysis.github.io/2019/12/24/shap3
#
# http://bongholee.com/2020/03/permutation-importance-partial-dependence-plot-%EC%A0%95%EB%A6%AC/
#
# https://data-newbie.tistory.com/254
